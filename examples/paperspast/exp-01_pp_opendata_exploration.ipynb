# %%
import pandas as pd

# %%
df = pd.read_csv(
    "https://natlib.govt.nz/files/paperspast/nlnz-newspaper-data-all-titles.csv"
)
df.head()
# Out:
#          packageName                                       title  year  \
# 0  AMBPA_1877.tar.gz  Akaroa Mail and Banks Peninsula Advertiser  1877
# 1  AMBPA_1878.tar.gz  Akaroa Mail and Banks Peninsula Advertiser  1878
# 2  AMBPA_1879.tar.gz  Akaroa Mail and Banks Peninsula Advertiser  1879
# 3  AMBPA_1880.tar.gz  Akaroa Mail and Banks Peninsula Advertiser  1880
# 4  AMBPA_1881.tar.gz  Akaroa Mail and Banks Peninsula Advertiser  1881
#
#        region  issues  pages  downloadSize   \
# 0  Canterbury     103    416    51,227,230
# 1  Canterbury     103    412    49,819,260
# 2  Canterbury     100    400    48,397,431
# 3  Canterbury     103    412    46,714,586
# 4  Canterbury     103    414    50,790,834
#
#                                                 link
# 0  https://paperspast.natlib.govt.nz/opendata/tit...
# 1  https://paperspast.natlib.govt.nz/opendata/tit...
# 2  https://paperspast.natlib.govt.nz/opendata/tit...
# 3  https://paperspast.natlib.govt.nz/opendata/tit...
# ...

# %%
df["title"].value_counts().plot.barh(figsize=(8, 16))
# Out:
# <Axes: ylabel='title'>

# %%
df["region"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='region'>
